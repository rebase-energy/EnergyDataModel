# %%
import erdantic as erd
import energydatamodel as edm

# %%
diagram = erd.create(edm.PVSystem)
diagram
# Out:
# EntityRelationshipDiagram(models=[DataClassModel(TimeSeries), DataClassModel(GeoLocation), DataClassModel(PVArray), DataClassModel(PVSystem)], edges=[Edge(source=DataClassModel(PVArray), source_field=<DataClassField: 'location', Optional[GeoLocation]>, target=DataClassModel(GeoLocation)), Edge(source=DataClassModel(PVArray), source_field=<DataClassField: 'timeseries', Optional[TimeSeries]>, target=DataClassModel(TimeSeries)), Edge(source=DataClassModel(PVSystem), source_field=<DataClassField: 'location', Optional[GeoLocation]>, target=DataClassModel(GeoLocation)), Edge(source=DataClassModel(PVSystem), source_field=<DataClassField: 'timeseries', Optional[TimeSeries]>, target=DataClassModel(TimeSeries)), Edge(source=DataClassModel(PVSystem), source_field=<DataClassField: 'pv_arrays', List[PVArray]>, target=DataClassModel(PVArray))])
